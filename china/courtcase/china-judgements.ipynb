# %% [markdown]
# ## China Judgement on Working

# %%
import numpy as np 
import pandas as pd

# %%
df_viet = pd.read_excel('./china-judgement-on-working.xlsx', '越南')

# %%
df_myan = pd.read_excel('./china-judgement-on-working.xlsx', '缅甸')
df_myan.head()
# Out:
#   date of judgement        city                         name  \
# 0        2016.10.08        云南芒市                王某某\n李某某\n唐某某
# 1        2016.08.11       云南腾冲市                     郭某某\n余某某
# 2               NaN  云南怒江傈僳族自治州                      阿福生\n邓白
# 3               NaN        广西东兴                           吴某
# 4               NaN        湖南长沙  姚孟军\n胡大儒\n刘建平\n周胜红\n孙平\n彭某某
#
#                                               prison  \
# 0    8个月\n2016.02.28-2016.10.27；\n判6个月，缓1年\n判6个月，缓1年
# 1  3年6月\n2016.03.05-2019.09.04；\n7月\n2016.03.05-2...
# 2                   11年\n2012.11.24-2023.11.23；\n11年
# 3                                               判1缓2
# 4  10年6月\n2013.03.26-2023.09.25；\n10年\n2013.03.18...
#
#                                 fine case info- type  \
# 0                       8k；\n5k；\n5k           肉块/屠体
# 1                       50k；\n\n\n5k              活体
# 2                        10k；\n\n20k              鳞片
# 3                                10k              活体
# ...

# %%
df_myan['fine']
# Out:
# 0                          8k；\n5k；\n5k
# 1                          50k；\n\n\n5k
# 2                           10k；\n\n20k
# 3                                   10k
# 4     50k；\n50k；\n50k；\n40k；\n40k；\n20k
# 5                                   10k
# 6                             15k；\n15k
# 7                               2k；\n2k
# 8                               3k；\n3k
# 9                                   10k
# 10                                   1k
# 11                                   6k
# 12                                   5k
# 13                                   8k
# 14                                   1k
# 15                                   2k
# 16                                  10k
# 17                                   3k
# 18                                  10k
# 19                              3k；\n3k
# 20                                   3k
# 21                                   6k
# 22                                  15k
# ...
