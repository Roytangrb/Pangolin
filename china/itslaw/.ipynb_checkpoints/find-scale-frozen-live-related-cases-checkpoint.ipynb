# %% [markdown]
# ## Find how many cases are related to frozen/live/scales (406 itslaw)

# %%
import pandas as pd
df = pd.read_csv('fulltext - fulltext.csv')

def get_df_filter_by_keywords(keywords):
    _df = df[df['text'].str.contains(keywords)].reset_index().drop('index', axis=1)
    print('total cases: ', len(_df))
    return _df

def print_para_with_keywords(_df, keywords):
    case_count = 0
    for text in _df['text']:
        ps = [p for p in text.split('\n') if any(keyword in p for keyword in keywords.split('|'))]
        if len(ps) > 0:
            case_count = case_count +1
            print(ps)
            print('\n')
    print('Total cases: ', case_count)

# %%
df_scale = get_df_filter_by_keywords('鳞片|甲壳|甲片|炮山甲|甲皮')
df_live = get_df_filter_by_keywords('活体') #幼体 +0
df_dead = get_df_filter_by_keywords('冻体|冰冻|速冻|冻肉|肉块|死体')
# Out:
# total cases:  163
# total cases:  171
# total cases:  143

# %%
print('percentage:', int(163 /406 *100), int(171/406*100), int(143/406*100))
# Out:
# percentage: 40 42 35

# %%
# print_para_with_keywords(df_scale, '鳞片')

# %% [markdown]
# # Geocode

# %%
import geocoder
import time
pd.options.mode.chained_assignment = None  # default='warn'

def get_df_lat_lng(_df):
    df_court = _df[['date', 'court']]
    success_count = 0
    for index, address in df_court['court'].iteritems():
        try:
            g = geocoder.baidu(address, key='CpEiE0gRf2ulr1YbkjpbPxhgolTuhX6l')
            if g.ok:
                df_court.loc[index, 'x'] = g.json['lat']
                df_court.loc[index, 'y'] = g.json['lng']
                df_court.loc[index, 'confidence'] = g.json['confidence']
                success_count = success_count + 1
            else :
                print(address, 'na')
        except:
            print('Exception')
    print(success_count)
    df_court.columns = ['year', 'court', 'lat', 'lng', 'confidence']
    return df_court

def to_csv(_df, name):
    _df.to_csv(name, encoding='utf_8_sig')
    
def reverse_code_province(_df):
    success_count = 0
    for index, row in _df.iterrows():
        try:
            g = geocoder.baidu([row.lat, row.lng], method='reverse', key='CpEiE0gRf2ulr1YbkjpbPxhgolTuhX6l')        
            if g.ok:
                _df.loc[index, 'province'] = g.json['raw']['addressComponent']['province'].replace('省', '')
                success_count = success_count + 1
            else :
                print(address, 'na')
        except:
            print('Exception')
    print (success_count)
    return _df

def count_per_province(_df):
    province_count = _df.groupby('province').count()
    province_count_json = list()
    province_count_total = 0
    for index, row in province_count.iterrows():
        province_count_total = province_count_total + row['year']
        province_count_json.append({'name': index, 'value':row['year']})
    print('total: ', province_count_total)
    return province_count_json

# %%
# df_scale_addr = get_df_lat_lng(df_scale)
# df_live_addr = get_df_lat_lng(df_live)
df_dead_addr = get_df_lat_lng(df_dead)

df_dead_addr.head()
# Out:
# 143
#    year       court        lat         lng  confidence
# 0  2016     勐海县人民法院  21.957359  100.445475        80.0
# 1  2018  广州市白云区人民法院  23.206978  113.270531        80.0
# 2  2018  钦州市钦南区人民法院  21.944469  108.657100        80.0
# 3  2017     江山市人民法院  28.756655  118.649222        80.0
# 4  2015     富阳市人民法院  30.065862  119.950352        80.0

# %%
# reverse_code_province(df_scale_addr)
# reverse_code_province(df_live_addr)
reverse_code_province(df_dead_addr)
# Out:
# 143
#      year            court        lat         lng  confidence province
# 0    2016          勐海县人民法院  21.957359  100.445475        80.0       云南
# 1    2018       广州市白云区人民法院  23.206978  113.270531        80.0       广东
# 2    2018       钦州市钦南区人民法院  21.944469  108.657100        80.0  广西壮族自治区
# 3    2017          江山市人民法院  28.756655  118.649222        80.0       浙江
# 4    2015          富阳市人民法院  30.065862  119.950352        80.0       浙江
# 5    2014       南京市鼓楼区人民法院  32.071248  118.750943        80.0       江苏
# 6    2015        珠海市中级人民法院  22.285510  113.543629        80.0       广东
# 7    2016           芒市人民法院  24.445034   98.592952        80.0       云南
# 8    2018          石门县人民法院  29.586346  111.370523        80.0       湖南
# 9    2013        钦州市中级人民法院  21.945027  108.667099        75.0  广西壮族自治区
# 10   2018   宁洱哈尼族彝族自治县人民法院  23.059789  101.050675        80.0       云南
# 11   2011       厦门市海沧区人民法院  24.490148  118.036839        75.0       福建
# 12   2016        益阳市中级人民法院  28.566108  112.369145        80.0       湖南
# 13   2006          绍兴县人民法院  30.091342  120.490320        80.0       浙江
# 14   2015          盈江县人民法院  24.712025   97.935889        80.0       云南
# 15   2014        钦州市中级人民法院  21.945027  108.667099        75.0  广西壮族自治区
# 16   2016     公诉机关勐海县人民检察院  21.960286  100.459135        80.0       云南
# 17   2015       河源市源城区人民法院  23.741044  114.706166        80.0       广东
# 18   2018       广州市天河区人民法院  23.117164  113.412310        75.0       广东
# 19   2011        广州市中级人民法院  23.134039  113.278767        80.0       广东
# 20   2019        三明市中级人民法院  26.252252  117.635055        80.0       福建
# 21   2015        保山市中级人民法院  25.137266   99.177736        80.0       云南
# 22   2019          利川市人民法院  30.306305  108.965380        80.0       湖北
# 23   2014          梁河县人民法院  24.819744   98.314551        80.0       云南
# 24   2017       柳州市鱼峰区人民法院  24.290437  109.432935        80.0  广西壮族自治区
# 25   2017          大田县人民法院  25.698650  117.852002        80.0       福建
# 26   2016          绍兴县人民法院  30.091342  120.490320        80.0       浙江
# 27   2016           芒市人民法院  24.445034   98.592952        80.0       云南
# 28   2017          诸暨市人民法院  29.720317  120.257593        80.0       浙江
# 29   2017        温州市中级人民法院  27.995940  120.701607        80.0       浙江
# ..    ...              ...        ...         ...         ...      ...
# 113  2013       深圳市罗湖区人民法院  22.561680  114.152479        75.0       广东
# 114  2017          兰溪市人民法院  29.209506  119.467672        80.0       浙江
# 115  2018          靖西市人民法院  23.148313  106.420267        75.0  广西壮族自治区
# 116  2015        衢州市中级人民法院  28.941703  118.879293        80.0       浙江
# 117  2017          景洪市人民法院  22.009499  100.773067        80.0       云南
# 118  2017       佛山市禅城区人民法院  23.021796  113.115498        90.0       广东
# 119  2017          诸暨市人民法院  29.720317  120.257593        80.0       浙江
# 120  2017       南宁市兴宁区人民法院  22.858226  108.373028        75.0  广西壮族自治区
# 121  2015      石家庄市长安区人民法院  38.059290  114.585129        80.0       河北
# 122  2017          诸暨市人民法院  29.720317  120.257593        80.0       浙江
# 123  2016       昆明市盘龙区人民法院  25.073730  102.725898        90.0       云南
# 124  2014       南京市鼓楼区人民法院  32.071248  118.750943        80.0       江苏
# 125  2015       珠海市金湾区人民法院  22.140958  113.358758        80.0       广东
# 126  2016          浦江县人民法院  29.453402  119.929115        70.0       浙江
# 127  2016          勐海县人民法院  21.957359  100.445475        80.0       云南
# 128  2014       普洱市思茅区人民法院  22.766361  100.974264        80.0       云南
# 129  2014       河源市源城区人民法院  23.741044  114.706166        80.0       广东
# 130  2016          勐海县人民法院  21.957359  100.445475        80.0       云南
# 131  2015       龙岩市新罗区人民法院  25.080791  117.030271        80.0       福建
# 132  2019       钦州市钦南区人民法院  21.944469  108.657100        80.0  广西壮族自治区
# 133  2016          永嘉县人民法院  28.153329  120.689550        75.0       浙江
# 134  2018           芒市人民法院  24.445034   98.592952        80.0       云南
# 135  2018          长乐市人民法院  25.959944  119.507468        80.0       福建
# 136  2016          东兴市人民法院  21.561145  107.996081        80.0  广西壮族自治区
# 137  2015          永嘉县人民法院  28.153329  120.689550        75.0       浙江
# 138  2016          柘荣县人民法院  27.239866  119.898036        80.0       福建
# 139  2014          福清市人民法院  25.730149  119.396451        80.0       福建
# 140  2018        云南省高级人民法院  25.073730  102.725898        90.0       云南
# 141  2018  西双版纳傣族自治州中级人民法院  22.004829  100.785358        80.0       云南
# 142  2019        广东省高级人民法院  23.077803  113.223386        80.0       广东
#
# [143 rows x 6 columns]

# %%
# to_csv(df_scale_addr, './scale-cases-all-addr.csv')
# to_csv(df_live_addr, './live-cases-all-addr.csv')
to_csv(df_dead_addr, './dead-cases-all-addr.csv')

# %%
count_per_province(df_scale_addr)
# Out:
# total:  163
# [{'name': '上海市', 'value': 2},
#  {'name': '云南', 'value': 78},
#  {'name': '内蒙古自治区', 'value': 1},
#  {'name': '北京市', 'value': 1},
#  {'name': '吉林', 'value': 1},
#  {'name': '四川', 'value': 3},
#  {'name': '安徽', 'value': 6},
#  {'name': '山东', 'value': 1},
#  {'name': '广东', 'value': 19},
#  {'name': '广西壮族自治区', 'value': 6},
#  {'name': '江苏', 'value': 2},
#  {'name': '江西', 'value': 2},
#  {'name': '河北', 'value': 1},
#  {'name': '河南', 'value': 1},
#  {'name': '浙江', 'value': 22},
#  {'name': '湖北', 'value': 1},
#  {'name': '湖南', 'value': 5},
#  {'name': '福建', 'value': 5},
#  {'name': '西藏自治区', 'value': 2},
#  {'name': '贵州', 'value': 1},
#  {'name': '辽宁', 'value': 2},
#  {'name': '重庆市', 'value': 1}]

# %%
count_per_province(df_live_addr)
# Out:
# total:  171
# [{'name': '上海市', 'value': 1},
#  {'name': '云南', 'value': 35},
#  {'name': '吉林', 'value': 1},
#  {'name': '广东', 'value': 33},
#  {'name': '广西壮族自治区', 'value': 26},
#  {'name': '江苏', 'value': 5},
#  {'name': '河北', 'value': 1},
#  {'name': '河南', 'value': 4},
#  {'name': '浙江', 'value': 40},
#  {'name': '海南', 'value': 2},
#  {'name': '湖南', 'value': 7},
#  {'name': '福建', 'value': 15},
#  {'name': '贵州', 'value': 1}]

# %%
count_per_province(df_dead_addr)
# Out:
# total:  143
# [{'name': '云南', 'value': 26},
#  {'name': '吉林', 'value': 1},
#  {'name': '广东', 'value': 28},
#  {'name': '广西壮族自治区', 'value': 20},
#  {'name': '江苏', 'value': 4},
#  {'name': '江西', 'value': 1},
#  {'name': '河北', 'value': 2},
#  {'name': '河南', 'value': 2},
#  {'name': '浙江', 'value': 37},
#  {'name': '海南', 'value': 1},
#  {'name': '湖北', 'value': 1},
#  {'name': '湖南', 'value': 6},
#  {'name': '福建', 'value': 13},
#  {'name': '重庆市', 'value': 1}]
